# %%
import pandas as pd

# %%
# load the data
import os
datapath = os.path.join("datasets", "")

oecd_bli = pd.read_csv(datapath + "oecd_bli.csv")

# %%
oecd_bli.head()
# Out:
#   LOCATION    Country INDICATOR                 Indicator MEASURE Measure  \
# 0      AUS  Australia   JE_LMIS  Labour market insecurity       L   Value
# 1      AUT    Austria   JE_LMIS  Labour market insecurity       L   Value
# 2      BEL    Belgium   JE_LMIS  Labour market insecurity       L   Value
# 3      CAN     Canada   JE_LMIS  Labour market insecurity       L   Value
# 4      CZE    Czechia   JE_LMIS  Labour market insecurity       L   Value
#
#   INEQUALITY Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0        TOT      Total        PC  Percentage               0     Units
# 1        TOT      Total        PC  Percentage               0     Units
# 2        TOT      Total        PC  Percentage               0     Units
# 3        TOT      Total        PC  Percentage               0     Units
# 4        TOT      Total        PC  Percentage               0     Units
#
#    Reference Period Code  Reference Period  Value  Flag Codes  Flags
# ...

# %%
oecd_bli["Country"].head()
# Out:
# 0    Australia
# 1      Austria
# 2      Belgium
# 3       Canada
# 4      Czechia
# Name: Country, dtype: object

# %%
oecd_bli["Country"]
# Out:
# 0        Australia
# 1          Austria
# 2          Belgium
# 3           Canada
# 4          Czechia
#            ...
# 2364    Costa Rica
# 2365    Costa Rica
# 2366    Costa Rica
# 2367    Costa Rica
# 2368    Costa Rica
# Name: Country, Length: 2369, dtype: object

# %%
oecd_bli.describe()
# Out:
#        PowerCode Code  Reference Period Code  Reference Period          Value  \
# count          2369.0                    0.0               0.0    2369.000000
# mean              0.0                    NaN               NaN    5299.220612
# std               0.0                    NaN               NaN   41894.336828
# min               0.0                    NaN               NaN       0.000000
# 25%               0.0                    NaN               NaN       7.100000
# 50%               0.0                    NaN               NaN      66.000000
# 75%               0.0                    NaN               NaN      88.000000
# max               0.0                    NaN               NaN  941162.000000
#
#        Flag Codes  Flags
# count         0.0    0.0
# mean          NaN    NaN
# std           NaN    NaN
# min           NaN    NaN
# 25%           NaN    NaN
# 50%           NaN    NaN
# 75%           NaN    NaN
# max           NaN    NaN

# %%
costa_rica_instances = oecd_bli[oecd_bli['Country'] == 'Costa Rica']

# %%
costa_rica_instances
# Out:
#      LOCATION     Country  INDICATOR  \
# 2320      CRI  Costa Rica    CG_SENG
# 2321      CRI  Costa Rica    HO_BASE
# 2322      CRI  Costa Rica    HO_HISH
# 2323      CRI  Costa Rica  PS_FSAFEN
# 2324      CRI  Costa Rica  PS_FSAFEN
# 2325      CRI  Costa Rica  PS_FSAFEN
# 2326      CRI  Costa Rica    HO_NUMR
# 2327      CRI  Costa Rica    IW_HADI
# 2328      CRI  Costa Rica    JE_EMPL
# 2329      CRI  Costa Rica    JE_EMPL
# 2330      CRI  Costa Rica    JE_EMPL
# 2331      CRI  Costa Rica    JE_LTUR
# 2332      CRI  Costa Rica    JE_LTUR
# 2333      CRI  Costa Rica    JE_LTUR
# 2334      CRI  Costa Rica   SC_SNTWS
# 2335      CRI  Costa Rica   SC_SNTWS
# 2336      CRI  Costa Rica   SC_SNTWS
# 2337      CRI  Costa Rica   SC_SNTWS
# 2338      CRI  Costa Rica   SC_SNTWS
# 2339      CRI  Costa Rica    ES_EDUA
# 2340      CRI  Costa Rica    ES_EDUA
# 2341      CRI  Costa Rica    ES_EDUA
# 2342      CRI  Costa Rica    ES_STCS
# 2343      CRI  Costa Rica    ES_STCS
# ...

# %%
oecd_bli.loc['Australia']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 oecd_bli.loc['Australia']
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
# ...

# %%
oecd_bli_2 = oecd_bli[oecd_bli["Country"] == "Australia"]

# %%
oecd_bli_2
# Out:
#      LOCATION    Country  INDICATOR  \
# 0         AUS  Australia    JE_LMIS
# 35        AUS  Australia    CG_SENG
# 108       AUS  Australia    HO_HISH
# 144       AUS  Australia  PS_FSAFEN
# 183       AUS  Australia  PS_FSAFEN
# 222       AUS  Australia  PS_FSAFEN
# 297       AUS  Australia    IW_HADI
# 331       AUS  Australia    IW_HNFW
# 360       AUS  Australia    JE_EMPL
# 399       AUS  Australia    JE_EMPL
# 438       AUS  Australia    JE_EMPL
# 477       AUS  Australia    JE_LTUR
# 514       AUS  Australia    JE_LTUR
# 551       AUS  Australia    JE_LTUR
# 588       AUS  Australia   JE_PEARN
# 623       AUS  Australia   SC_SNTWS
# 662       AUS  Australia   SC_SNTWS
# 701       AUS  Australia   SC_SNTWS
# 740       AUS  Australia   SC_SNTWS
# 778       AUS  Australia   SC_SNTWS
# 816       AUS  Australia    ES_EDUA
# 854       AUS  Australia    ES_EDUA
# 892       AUS  Australia    ES_EDUA
# 930       AUS  Australia    ES_STCS
# 967       AUS  Australia    ES_STCS
# ...
