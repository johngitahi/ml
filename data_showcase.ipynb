# %%
import pandas as pd

# %%
#Load the oecd bli data
import os
datapath = os.path.join("datasets", "")

oecd_bli = pd.read_csv(datapath + "oecd_bli.csv")

oecd_bli.head(3)
# Out:
#   LOCATION    Country INDICATOR                 Indicator MEASURE Measure  \
# 0      AUS  Australia   JE_LMIS  Labour market insecurity       L   Value
# 1      AUT    Austria   JE_LMIS  Labour market insecurity       L   Value
# 2      BEL    Belgium   JE_LMIS  Labour market insecurity       L   Value
#
#   INEQUALITY Inequality Unit Code        Unit  PowerCode Code PowerCode  \
# 0        TOT      Total        PC  Percentage               0     Units
# 1        TOT      Total        PC  Percentage               0     Units
# 2        TOT      Total        PC  Percentage               0     Units
#
#    Reference Period Code  Reference Period  Value  Flag Codes  Flags
# 0                    NaN               NaN    3.1         NaN    NaN
# 1                    NaN               NaN    2.3         NaN    NaN
# 2                    NaN               NaN    2.4         NaN    NaN

# %%
oecd_truths = oecd_bli["INEQUALITY"]=="TOT"

# %%
oecd_truths
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2364    False
# 2365    False
# 2366     True
# 2367    False
# 2368    False
# Name: INEQUALITY, Length: 2369, dtype: bool

# %%
oecd_truths.head(2)
# Out:
# 0    True
# 1    True
# Name: INEQUALITY, dtype: bool

# %%
oecd_finals = oecd_bli[oecd_truths]

# %%
oecd_truths
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2364    False
# 2365    False
# 2366     True
# 2367    False
# 2368    False
# Name: INEQUALITY, Length: 2369, dtype: bool

# %%
oecd_finals
# Out:
#      LOCATION     Country INDICATOR                          Indicator  \
# 0         AUS   Australia   JE_LMIS           Labour market insecurity
# 1         AUT     Austria   JE_LMIS           Labour market insecurity
# 2         BEL     Belgium   JE_LMIS           Labour market insecurity
# 3         CAN      Canada   JE_LMIS           Labour market insecurity
# 4         CZE     Czechia   JE_LMIS           Labour market insecurity
# ...       ...         ...       ...                                ...
# 2352      CRI  Costa Rica    HS_LEB                    Life expectancy
# 2355      CRI  Costa Rica   HS_SFRH               Self-reported health
# 2358      CRI  Costa Rica   SW_LIFS                  Life satisfaction
# 2363      CRI  Costa Rica   PS_REPH                      Homicide rate
# 2366      CRI  Costa Rica   WL_EWLH  Employees working very long hours
#
#      MEASURE Measure INEQUALITY Inequality Unit Code           Unit  \
# ...

# %%
oecd_bli = oecd_finals.pivot(index="Country", columns="Indicator", values="Value")
oecd_bli.head()
# Out:
# Indicator  Air pollution  Dwellings without basic facilities  \
# Country
# Australia            6.7                                 NaN
# Austria             12.2                                 0.8
# Belgium             12.8                                 0.7
# Brazil              11.7                                 6.7
# Canada               7.1                                 0.2
#
# Indicator  Educational attainment  Employees working very long hours  \
# Country
# Australia                    84.0                               12.5
# Austria                      86.0                                5.3
# Belgium                      80.0                                4.3
# Brazil                       57.0                                5.6
# Canada                       92.0                                3.3
#
# Indicator  Employment rate  Feeling safe walking alone at night  \
# Country
# Australia             73.0                                 67.0
# ...

# %%
oecd_bli['Life satisfaction'].head()
# Out:
# Country
# Australia    7.1
# Austria      7.2
# Belgium      6.8
# Brazil       6.1
# Canada       7.0
# Name: Life satisfaction, dtype: float64

# %% [markdown]
# ## **Load the GDP per capita data**

# %%
# read the data
gdp_per_capita = pd.read_excel(datapath + "imf_gdp.xls", engine="pyxlsb")

# sneak peek of data shape
gdp_per_capita.head()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# Cell In[57], line 2
#       1 # read the data
# ----> 2 gdp_per_capita = pd.read_excel(datapath + "imf_gdp.xls", engine="pyxlsb")
#       4 # sneak peek of data shape
#       5 gdp_per_capita.head()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/excel/_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476 if not isinstance(io, ExcelFile):
#     477     should_close = True
# --> 478     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479 elif engine and engine != io.engine:
#     480     raise ValueError(
# ...
